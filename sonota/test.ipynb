# %%
# %pip install deep-translator
import pandas as pd
import asyncio
# Out:
# Requirement already satisfied: deep-translator in c:\users\yagin\appdata\local\programs\python\python313\lib\site-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\users\yagin\appdata\local\programs\python\python313\lib\site-packages (from deep-translator) (4.14.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\yagin\appdata\local\programs\python\python313\lib\site-packages (from deep-translator) (2.32.5)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\yagin\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\yagin\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yagin\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yagin\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yagin\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yagin\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from deep_translator import GoogleTranslator
def honya(text):
    return GoogleTranslator(source='auto', target='ja').translate(text)

honya("hello")
# Out:
# 'こんにちは'

# %%
import random
money = random.randint(0, 3000)
print('【現在の所持金】 ')
if money >= 1500:
    print('結果:'+str(money) +'円'+ '  ' +"沢山お買い物しましょう")
else: 
    print('結果:'+str(money) +'円'+ '  ' +"少し節約すべきですね")
# Out:
# 【現在の所持金】
# 結果:891円  少し節約すべきですね

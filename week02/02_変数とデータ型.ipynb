# %% [markdown]
# # 第1章 変数とデータ型
#
# Variables and data types

# %% [markdown]
# ## 1.1 式と演算
#
# 数値の演算と算術演算子の種類

# %% [markdown]
# まず、プログラミングを学習する上で最初に行う儀式があります。それは、"Hello World!"と表示することです。やってみましょう。

# %% [markdown]
# Welcome to programming. Of course, we begin with "Hello World!"
#
# Learn how to print text in Python using the ```print``` command

# %%
# printing numbers
print(19999)
print(10)

# %%
# printing text
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### 1.1.1 Single and double quotes
# 上記のように、```print```**関数**をつかうことで画面出力を行えます。**文字を出力する際は** "Hello World" のように**```" "```**や**```' '```**で文字を括る必要があります。```" "```でも```' '```でも、どちらでも良いです。()の中には数値も入れることができます。

# %% [markdown]
# ```print``` is a python *function* that allows us to define an output. You can use single quotes or double quotes, just make sure to be consistent (i.e. you can't start with a single quote and end with a double quote). The parentheses ```( )``` allows you to add *arguments* to the function. More on this as we move forward.

# %% [markdown]
# 🧐では質問：どういうシチュエーションでsingle quotesを使ったり、double quotesを使ったりするのでしょうか？

# %% [markdown]
# ### 1.1.2 Comments
# Notice the ```#``` signs. These are comments within your python code. Use comments as often as you possibly can!

# %%
# this is a comment
print("こっちは実行される")
# print("こっちは実行されない")
# Out:
# こっちは実行される

# %% [markdown]
# ### 1.1.3 Math
# プログラムの得意分野は何といっても計算です。計算させてみましょう。

# %% [markdown]
# Any coding language loves to do math. Let's start with some simple equations.

# %%
print(1 + 1)
# Out:
# 2

# %%
print(1 + 7) #足し算　
print(1 - 7) #引き算
print(1 * 7) #掛け算
print(1 / 7) #割り算
print(1 // 7)#割り算の商　どんなときに使うのか？
print(1 % 7) #割り算の余り
print(2 ** 3)#べき乗（左の例は2の3乗：2*2*2）
# Out:
# 8
# -6
# 7
# 0.14285714285714285
# 0
# 1
# 8

# %% [markdown]
# 四則演算はもちろんですが、割り算の**余り(%)**なども結構使う機会が多いです。また、上記のプログラムにおいて、```#```の後に足し算や引き算といった説明書きがあります。```#```の後の文字や文章はプログラムとして解釈されず、プログラムを読む人間向けのコメントとして扱われます。これを**コメントアウト**と言います。

# %% [markdown]
# **文字の足し算（結合）もできる**

# %% [markdown]
# You can also "add" text strings.

# %%
print("Reitaku" + "University")

# %% [markdown]
# #### 🧐Code challenge
# Make the output read "Reitaku University" (with a space in between)
#
# 出力が "Reitaku University"（間にスペースあり）となるようにしましょう

# %% [markdown]
# **数値も" "や' 'でくくることによって文字として扱うことができます**

# %% [markdown]
# Numbers can be treated as text/strings by putting quotes around them.

# %%
print(1+2)
print("1"+"2")

# %% [markdown]
# **文字列と数値の足し算はできない**

# %% [markdown]
# If you add strings to numbers, the numbers are treated as strings.

# %%
print("Reitaku" + "University" + "2020")

# %% [markdown]
# ## 1.2 変数 Variables

# %% [markdown]
# プログラムには「変数」という仕組みがあります。プログラムを使うと便利な理由の1つです。

# %% [markdown]
# Variables is a fundamental part of coding. Let's find out why it is useful. Consider the following code:

# %%
print("掛け算九九における2の段の答えは")
print(2 * 1)
print(2 * 2)
print(2 * 3)
print(2 * 4)
print(2 * 5)
print(2 * 6)
print(2 * 7)
print(2 * 8)
print(2 * 9)
# Out:
# 掛け算九九における2の段の答えは
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %% [markdown]
# これを5の段に変えようと思うと、最初の2をすべて5に書き換えないといけません。かなり大変です。そこで、変数を使います。変数の使い方は
# ```
# 変数 = 値
# ```
# のようにプログラムを書き、「変数に値を代入(保存）する」という意味になります。私たちがこれまで慣れ親しんできた数式では、「変数と値は等しい」という意味でしたが、プログラムでは「=」は代入を意味します。（ちなみに「等しい」は「==」）

# %% [markdown]
# Changing the ```2``` to a ```5``` would be quite a time consuming task. This is where using a variable comes in handy.

# %% [markdown]
# #### 🧐Code challenge
#
# それではチャレンジタイム！
#
# 下のセルで変数を使って掛け算を５の段に変えよう。

# %%
# ５の段で九九計算
print("掛け算九九における5の段の答えは")
print(5 * 1)
print(5 * 2)
print(5 * 3)
print(5 * 4)
print(5 * 5)
print(5 * 6)
print(5 * 7)
print(5 * 8)
print(5 * 9)
# Out:
# 掛け算九九における5の段の答えは
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
#
#
#
#
#
#
#
#
#
# 答え：

# %%
x = 6 #xという変数に、5という数値を代入
print("掛け算九九における6の段の答えは")
print(x * 1) #→5 × 1
print(x * 2) #→5 × 2
print(x * 3) #→5 × 3
print(x * 4) #→5 × 4
print(x * 5) #→5 × 5
print(x * 6) #→5 × 6
print(x * 7) #→5 × 7
print(x * 8) #→5 × 8
print(x * 9) #→5 × 9
# Out:
# 掛け算九九における6の段の答えは
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54

# %% [markdown]
# すると、xへの代入と2行目の`print`文のみを変更すれば良いので、らくちん。
# ※後ほど、2行目も書き換える必要ない方法を説明します。

# %% [markdown]
# It's like magic! By creating a variable ```x``` and defining it to be a number (in this case ```5```), you only have to change the code in one place to then change the number to a new value.

# %% [markdown]
# もう一つの例：演習の長さを計算するモデル

# %%
radius = 10  # 半径 radius
print('半径が10の円の円周の長さは')
print(2 * radius * 3.14)
# Out:
# 半径が10の円の円周の長さは
# 62.800000000000004

# %% [markdown]
# #### 🧐Code challenge
# 下のセルに半径が3の円の面積$(\pi r^2)$を計算するプログラムを書きましょう。

# %%
radius=3
print('半径が'+str(radius)+'の円の面積は')
print(3.14*radius**2)
# Out:
# 半径が3の円の面積は
# 28.26

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
#
#
#
#
#
#
#
#
#
# 答え：

# %%
radius = 3  # 半径 radius
print('半径が3の円の面積は')
print(3.14 * radius **2)
# Out:
# 半径が3の円の面積は
# 28.26

# %% [markdown]
# #### 🧐Code challenge
# 変数 $x$ に2を代入し、$x^2+2x+3$の値を計算して出力するプログラムを書きましょう。

# %%
x=2

print(x**2+2*x+3)
# Out:
# 11

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
#
#
#
#
#
#
#
#
#
# 答え：

# %%
x=2
print(x**2 + 2*x +3)
# Out:
# 11

# %% [markdown]
# ### 1.2.2 変数名のルール

# %%
#このプログラムは実行しないでください
if = 2
print(if / 3)
# Out:
#   Cell In[18], line 2
#     if = 2
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 変数名は基本、好きにつけていいのですが、いくつかルールがあります。
# 特に注意しないといけないのが、if, for, whileなどのPythonで使用されている単語は使えません。
#
# Other rules

# %%
#Legal variable names:
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

#Illegal variable names:
2myvar = "John"
my-var = "John"
my var = "John"

# %% [markdown]
# ### 1.2.4 まとめて代入

# %%
x,y = 1,2
print(x)
print(y)
print(x / y)
# Out:
# 1
# 2
# 0.5

# %% [markdown]
# #### 🧐Code challenge
# $x$には2を、 $y$には3を代入し、$x^2+2xy+y^2$の値を出力するプログラムを書きましょう。ただし、まとめて代入を使用すること。

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
#
#
#
#
#
#
#
#
#
# 答え：

# %%
x,y=2,3
print(x**2 +2*x*y + y **2 )

# %% [markdown]
# ### 1.2.5 自分自身への代入

# %%
age = 18
print('あなたの年齢は')
print(age)
age + 1
print('あなたの来年の年齢は')
print(age)
# Out:
# あなたの年齢は
# 18
# あなたの来年の年齢は
# 18

# %% [markdown]
# #### 🧐Code challenge
# どのようにすれば、年齢を加算できるでしょうか？
# 4行目と７行目にプログラムを追加しましょう。

# %%
age = 18
print('あなたの年齢は')
print(age)

age += 1
print('あなたの来年の年齢は')
print(age)

age += 1
print('あなたのさ来年の年齢は')
print(age)
# Out:
# あなたの年齢は
# 18
# あなたの来年の年齢は
# 19
# あなたのさ来年の年齢は
# 20

# %% [markdown]
# ↑もともとの`age`に1を足して、ageに上書きするイメージ

# %% [markdown]
# ### 1.2.6 複合代入演算子
#
# こう言うやり方もあるよ！
#
# ```+=```でショートカット

# %%
age = 18

age += 1 #age = age + 1
print('あなたの来年の年齢は')
print(age)

age += 1 
print('あなたの再来年の年齢は')
print(age)

# %% [markdown]
# ### 1.2.7 キーボード入力値の代入
# 標準入力

# %%
s = input()
print(s)

# %% [markdown]
# 質問形式にする

# %%
name = input('あなたの名前を入力してください >>')
print('あなたの名前は'+ name + 'です')
# Out:
# あなたの名前はaaaです

# %% [markdown]
# キーボードからの入力値を数値として扱う

# %%
age = input('あなたの年齢を入力してください >>')
print('あなたは' + age + '歳です')

# %%
age = int(input('あなたの年齢を入力してください >>'))
age += 1
print('あなたは来年' + str(age) + '歳です')
# Out:
# あなたは来年20歳です

# %% [markdown]
# おや。エラーになってしまいました。

# %% [markdown]
# ## 1.3 データ型

# %%
x = 10
type(x)

# %%
name = 'れいたく'
type(name)

# %% [markdown]
# input()で受け取った入力のデータ型を調べよう。

# %%
type(age)

# %% [markdown]
# ### 1.3.2 データ型の変換

# %%
age = input('あなたの年齢を入力してください >>')
age = int(age) #int()で整数に変換
age += 10
print('あなたは10年後' + str(age) + '歳です') #str()で文字に変換

# %% [markdown]
# **==メモ：データ型の変換について==**
#
# 基本的なものをまとめます。
# 整数へ変換：```int()```
# 小数点へ変換：```float()```
# 文字へ変換：```str()```

# %% [markdown]
# ### 1.2.3 文字列の中に数値を埋め込む
# ```format```　関数は、Pythonの文字列フォーマットを行うための強力なツールです。この関数を使用すると、文字列内にプレースホルダーを配置し、そこに値を挿入することができます。以下にformat関数の主な特徴と使用方法を説明します:

# %%
radius = 5  # 半径 radius
print('半径が　5の円の円周の長さは')
print(radius * 2 * 3.14)

# %%
radius =15000
print('半径が{}の円の円周の長さは'.format(radius))
print(radius * 2 * 3.14)

# %%
#変数の値を複数個所に埋め込みたい場合は、次のように埋め込みたい個所に{}を、format関数の中には出力したい順番に変数を,区切りで入れます。
age = 25
print('今の年齢は{}歳です。来年は{}歳になります。'.format(age,age+1))

# %% [markdown]
# #### f-string
#
# ```f-string```（フォーマット済み文字列リテラル）は、Python 3.6以降で導入された文字列フォーマットの新しい方法です。```f-string```は、format()メソッドよりも簡潔で読みやすく、多くの場合でより高速です。
#
# ##### 基本的な使い方
# ```f-string```は、文字列の前にfまたはFを付けて作成します。中括弧{}内に直接Pythonの式を書くことができます。

# %%
radius = 500
print(f'半径が{radius}の円の円周の長さは')
print(radius * 2 * 3.14)

# %%
#変数の値を複数個所に埋め込みたい場合は、次のように埋め込みたい個所に{変数名}を入れてあげれば良いです。
age = 41
print(f'今の年齢は{age}歳です。来年は{age+1}歳になります。さ来年は{age+2}歳になります。')

# %% [markdown]
# たとえば冒頭の掛け算のプログラムは、2行目を次のように書き換えることで、1行目の変数のところだけを書き換えればよくなります。

# %%
x = 13 #xという変数に、5という数値を代入
print(f'掛け算九九における{x}の段の答えは')
print(x * 1) #→5 × 1
print(x * 2) #→5 × 2
print(x * 3) #→5 × 3
print(x * 4) #→5 × 4
print(x * 5) #→5 × 5
print(x * 6) #→5 × 6
print(x * 7) #→5 × 7
print(x * 8) #→5 × 8
print(x * 9) #→5 × 9
